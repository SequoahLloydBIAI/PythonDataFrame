# %%
from google_play_scraper import app, Sort, reviews_all
from app_store_scraper import AppStore
import pandas as pd
import numpy as np
import json, os, uuid

# %%
g_reviews = reviews_all(
        "com.goodsam.gscamping",
        sleep_milliseconds=0, # defaults to 0
        lang='en', # defaults to 'en'
        country='us', # defaults to 'us'
        sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
    )
a_reviews = AppStore('us', 'good-sam-camping', '449060020')
a_reviews.review()
# Out:
# 2022-09-22 07:13:21,148 [INFO] Base - Initialised: AppStore('us', 'good-sam-camping', 449060020)
# 2022-09-22 07:13:21,151 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/good-sam-camping/id449060020
# 2022-09-22 07:13:26,277 [INFO] Base - [id:449060020] Fetched 240 reviews (240 fetched in total)
# 2022-09-22 07:13:31,792 [INFO] Base - [id:449060020] Fetched 500 reviews (500 fetched in total)
# 2022-09-22 07:13:37,597 [INFO] Base - [id:449060020] Fetched 780 reviews (780 fetched in total)
# 2022-09-22 07:13:38,822 [INFO] Base - [id:449060020] Fetched 832 reviews (832 fetched in total)

# %%
g_df = pd.DataFrame(np.array(g_reviews),columns=['review'])
g_df2 = g_df.join(pd.DataFrame(g_df.pop('review').tolist()))

g_df2.drop(columns={'userImage', 'reviewCreatedVersion'},inplace = True)
g_df2.rename(columns= {'score': 'rating','userName': 'user_name', 'reviewId': 'review_id', 'content': 'review_description', 'at': 'review_date', 'replyContent': 'developer_response', 'repliedAt': 'developer_response_date', 'thumbsUpCount': 'thumbs_up'},inplace = True)
g_df2.insert(loc=0, column='source', value='Google Play')
g_df2.insert(loc=3, column='review_title', value=None)
g_df2['laguage_code'] = 'en'
g_df2['country_code'] = 'us'
g_df2
# Out:
#           source                             review_id        user_name  \
# 0    Google Play  478c1b83-5d99-4980-8ace-161a973f0dd2             PB44
# 1    Google Play  4def1479-3c41-4afb-a84d-9770ff76975b  Linda Josephson
# 2    Google Play  e41f8d03-3366-4b3f-94e4-1873a2619dbd      Tom Vodicka
# 3    Google Play  8b717658-33ef-4030-958a-b77bd423ff04     Leisa Corbin
# 4    Google Play  233e95ee-e8ff-42db-b52f-a69ff0499fa9  Kenny Bourgault
# ..           ...                                   ...              ...
# 481  Google Play  1d6c5c28-c196-432d-b7e0-a52d540f76ed    A Google user
# 482  Google Play  a33f6160-0899-4b55-af43-f56ef9fb8814    A Google user
# 483  Google Play  3877b295-0e89-4481-9fe8-bc58e501b5ea    A Google user
# 484  Google Play  6dae436d-97bd-4d7b-89be-a910347d6218    A Google user
# 485  Google Play  6dc34b30-4e9e-4e48-a1cb-92f4afef7a87    A Google user
#
#     review_title                                 review_description  rating  \
# 0           None  Cannot log into my account. There is a 'join' ...       1
# 1           None  Keeps asking for my Good Sam membership number...       2
# 2           None    I have a new tablet and the app keeps crashing.       1
# 3           None                                          Good app.       5
# 4           None  @FrankAtHome said it perfectly but I will add,...       1
# ..           ...                                                ...     ...
# 481         None                                     Very impressed       5
# 482         None         I've been waiting for this app on Android!       5
# 483         None  Does not work on my DROID MAXX. With all locat...       5
# 484         None  I am REALLY liking what I see here.  I did a q...       5
# 485         None                                    Very useful app       5
#
#      thumbs_up         review_date developer_response developer_response_date  \
# 0            0 2022-09-07 20:53:09               None                     NaT
# 1            0 2022-08-21 15:09:19               None                     NaT
# 2            0 2022-08-20 07:23:50               None                     NaT
# 3            0 2022-08-14 12:10:10               None                     NaT
# 4            2 2022-08-11 11:22:51               None                     NaT
# ..         ...                 ...                ...                     ...
# 481          0 2013-08-13 22:05:59               None                     NaT
# 482          0 2013-08-13 20:06:15               None                     NaT
# 483          1 2013-08-07 01:46:52               None                     NaT
# 484          0 2013-08-05 22:52:19               None                     NaT
# 485          0 2013-08-05 20:44:15               None                     NaT
#
#     laguage_code country_code
# 0             en           us
# 1             en           us
# 2             en           us
# 3             en           us
# 4             en           us
# ..           ...          ...
# 481           en           us
# 482           en           us
# 483           en           us
# 484           en           us
# 485           en           us
#
# [486 rows x 12 columns]

# %%
a_df = pd.DataFrame(np.array(a_reviews.reviews),columns=['review'])
a_df2 = a_df.join(pd.DataFrame(a_df.pop('review').tolist()))

a_df2.drop(columns={'isEdited'},inplace = True)
a_df2.insert(loc=0, column='source', value='App Store')
a_df2['developer_response_date'] = None
a_df2['thumbs_up'] = None
a_df2['laguage_code'] = 'en'
a_df2['country_code'] = 'us'
a_df2.insert(loc=1, column='review_id', value=[uuid.uuid4() for _ in range(len(a_df2.index))])
a_df2.rename(columns= {'review': 'review_description','userName': 'user_name', 'date': 'review_date','title': 'review_title', 'developerResponse': 'developer_response'},inplace = True)
a_df2 = a_df2.where(pd.notnull(a_df2), None)
a_df2
# Out:
#         source                             review_id         review_date  \
# 0    App Store  23b329d0-fb0b-4973-8cc7-dc7267a54df9 2019-07-04 15:07:22
# 1    App Store  8ca40f11-14b9-4409-a129-57b4ed539d25 2021-09-25 15:14:03
# 2    App Store  916a5ee4-8c76-499a-88f7-668aeee3f4af 2019-09-28 15:18:15
# 3    App Store  cb50080e-dda9-439f-9e4d-8716836ee40d 2021-12-27 13:23:33
# 4    App Store  b094f6c1-098e-4e0f-ac1d-acf420b232a4 2022-09-05 14:17:25
# ..         ...                                   ...                 ...
# 827  App Store  4ce5bb40-e549-4263-8fd3-f473329681ca 2013-10-16 17:28:53
# 828  App Store  627d3008-5fc6-406d-9a31-8c3a40c24897 2013-10-10 16:45:13
# 829  App Store  264f059a-5dba-4a83-98fc-859a84aebe40 2013-10-08 13:57:17
# 830  App Store  5e164d86-7a95-4d1c-9368-732ddca99bce 2013-10-07 16:15:23
# 831  App Store  9f53b208-cc44-44ce-89d3-13a54ced1341 2012-06-08 16:41:02
#
#                      review_title  rating         user_name  \
# 0    A digital card seems obvious       2   Betsy & Charlie
# 1                App is Worthless       1         Cablerock
# 2             App could be better       3   Climbergirl2002
# 3                One of the best!       5       Just Me 358
# 4                        Good Sam       5            AVO241
# ..                            ...     ...               ...
# 827              Good Sam camping       1  Full time camper
# 828            Needs to be fixed.       1        Ac52engine
# 829              This App is Dead       1       Chinook-Man
# 830         Doesn't Work on IOS 7       1           Carla55
# 831                     New rv'rs       5           Foresnj
#
#                                     review_description  \
# 0    I’m surprised to see you can’t access your mem...
# 1    I see no difference between Good Sam parks and...
# 2    Right now the application is somewhat useless ...
# 3    I use all of the RV Park apps on a regular bas...
# 4    I think a application for scanning prices shou...
# ..                                                 ...
# 827  What happened to the iOS 7 update?  We used to...
# 828  This app was great till iOS7, now is crashes o...
# 829  Working great until iOS 7 update. Now will not...
# 830  Worked before iOS 7 now only crashes on load. ...
# 831  We are new to camping with an rv .this app is ...
#
#                                     developer_response  \
# 0                                                 None
# 1    {'id': 22517644, 'body': 'Hello, we understand...
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 827                                               None
# 828                                               None
# 829                                               None
# 830                                               None
# 831                                               None
#
#     developer_response_date thumbs_up laguage_code country_code
# 0                      None      None           en           us
# 1                      None      None           en           us
# 2                      None      None           en           us
# 3                      None      None           en           us
# 4                      None      None           en           us
# ..                      ...       ...          ...          ...
# 827                    None      None           en           us
# 828                    None      None           en           us
# 829                    None      None           en           us
# 830                    None      None           en           us
# 831                    None      None           en           us
#
# [832 rows x 12 columns]

# %%
result = pd.concat([g_df2,a_df2])
result
# Out:
#           source                             review_id         user_name  \
# 0    Google Play  478c1b83-5d99-4980-8ace-161a973f0dd2              PB44
# 1    Google Play  4def1479-3c41-4afb-a84d-9770ff76975b   Linda Josephson
# 2    Google Play  e41f8d03-3366-4b3f-94e4-1873a2619dbd       Tom Vodicka
# 3    Google Play  8b717658-33ef-4030-958a-b77bd423ff04      Leisa Corbin
# 4    Google Play  233e95ee-e8ff-42db-b52f-a69ff0499fa9   Kenny Bourgault
# ..           ...                                   ...               ...
# 827    App Store  4ce5bb40-e549-4263-8fd3-f473329681ca  Full time camper
# 828    App Store  627d3008-5fc6-406d-9a31-8c3a40c24897        Ac52engine
# 829    App Store  264f059a-5dba-4a83-98fc-859a84aebe40       Chinook-Man
# 830    App Store  5e164d86-7a95-4d1c-9368-732ddca99bce           Carla55
# 831    App Store  9f53b208-cc44-44ce-89d3-13a54ced1341           Foresnj
#
#               review_title                                 review_description  \
# 0                     None  Cannot log into my account. There is a 'join' ...
# 1                     None  Keeps asking for my Good Sam membership number...
# 2                     None    I have a new tablet and the app keeps crashing.
# 3                     None                                          Good app.
# 4                     None  @FrankAtHome said it perfectly but I will add,...
# ..                     ...                                                ...
# 827       Good Sam camping  What happened to the iOS 7 update?  We used to...
# 828     Needs to be fixed.  This app was great till iOS7, now is crashes o...
# 829       This App is Dead  Working great until iOS 7 update. Now will not...
# 830  Doesn't Work on IOS 7  Worked before iOS 7 now only crashes on load. ...
# 831              New rv'rs  We are new to camping with an rv .this app is ...
#
#      rating thumbs_up         review_date developer_response  \
# 0         1         0 2022-09-07 20:53:09               None
# 1         2         0 2022-08-21 15:09:19               None
# 2         1         0 2022-08-20 07:23:50               None
# 3         5         0 2022-08-14 12:10:10               None
# 4         1         2 2022-08-11 11:22:51               None
# ..      ...       ...                 ...                ...
# 827       1      None 2013-10-16 17:28:53               None
# 828       1      None 2013-10-10 16:45:13               None
# 829       1      None 2013-10-08 13:57:17               None
# 830       1      None 2013-10-07 16:15:23               None
# 831       5      None 2012-06-08 16:41:02               None
#
#     developer_response_date laguage_code country_code
# 0                       NaT           en           us
# 1                       NaT           en           us
# 2                       NaT           en           us
# 3                       NaT           en           us
# 4                       NaT           en           us
# ..                      ...          ...          ...
# 827                     NaT           en           us
# 828                     NaT           en           us
# 829                     NaT           en           us
# 830                     NaT           en           us
# 831                     NaT           en           us
#
# [1318 rows x 12 columns]

# %%
a_df2.to_csv('Good_Sam_Camping_a.csv')

# %%
g_df2.to_csv('Good_Sam_Camping_g.csv')
